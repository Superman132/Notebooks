# %%
import random
import numpy

a = numpy.array([[4,6],[-1,5]])

b = numpy.array([[7,-6, 2],[1,-3,-3]])

a @ b
# Out:
# array([[ 34, -42, -10],
#        [ -2,  -9, -17]])

# %% [markdown]
# [ [-4, 16+3k], [-10, k-12] ]
#
# [[-4, 10], [-16-3k, k-12]]
#
# 16+3k = 10
# k=-2
